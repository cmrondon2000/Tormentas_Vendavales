# %% [markdown]
# <a href="https://colab.research.google.com/github/cmrondon2000/Tormentas_Vendavales/blob/main/tormentas2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install xarray netCDF4 matplotlib
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.3/9.3 MB 50.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 49.8 MB/s eta 0:00:00
# ...

# %%
import xarray as xr

# Ruta al archivo (ajústala según tu caso)
file_path = 'WWLLN_sd_1d_2005.nc'

# Abrir archivo
ds = xr.open_dataset(file_path)

# Ver las variables disponibles
ds
# Out:
# <xarray.Dataset> Size: 3MB
# Dimensions:         (nlat: 180, nlon: 360, nmon: 12)
# Dimensions without coordinates: nlat, nlon, nmon
# Data variables:
#     lat             (nlat) float32 720B ...
#     lon             (nlon) float32 1kB ...
#     mon             (nmon) int8 12B ...
#     stroke_density  (nlon, nlat, nmon) float32 3MB ...
# Attributes:
#     Summary:  Monthly WWLLN stroke density during 2005
#     Source:   Katrina Virts (katrina.virts@uah.edu)

# %%
ds_lat = ds.lat

# %%
display(ds_lat)
# Out:
# <xarray.DataArray 'lat' (nlat: 180)> Size: 720B
# [180 values with dtype=float32]
# Dimensions without coordinates: nlat
# Attributes:
#     Long name:  Latitude
#     Units:      Degrees north

# %%
ds
# Out:
# <xarray.Dataset> Size: 3MB
# Dimensions:         (nlat: 180, nlon: 360, nmon: 12)
# Dimensions without coordinates: nlat, nlon, nmon
# Data variables:
#     lat             (nlat) float32 720B ...
#     lon             (nlon) float32 1kB ...
#     mon             (nmon) int8 12B ...
#     stroke_density  (nlon, nlat, nmon) float32 3MB ...
# Attributes:
#     Summary:  Monthly WWLLN stroke density during 2005
#     Source:   Katrina Virts (katrina.virts@uah.edu)

# %%
# Ruta al archivo (ajústala según tu caso)
file_path = 'WWLLN_th_2005.nc'

# Abrir archivo
ds_2005 = xr.open_dataset(file_path)

# Ver las variables disponibles
ds_2005
# Out:
# <xarray.Dataset> Size: 622MB
# Dimensions:        (nlat: 3600, nlon: 7200, nmon: 12)
# Dimensions without coordinates: nlat, nlon, nmon
# Data variables:
#     lat            (nlat) float32 14kB ...
#     lon            (nlon) float32 29kB ...
#     mon            (nmon) int8 12B ...
#     thunder_hours  (nlon, nlat, nmon) int16 622MB ...
# Attributes:
#     Summary:  Monthly WWLLN thunder hours during 2005
#     Source:   Katrina Virts (katrina.virts@uah.edu)

# %% [markdown]
# # Task
# Analyze the NetCDF files "ds_2005.nc", "ds_2006.nc", "ds_2007.nc", "ds_2008.nc", "ds_2009.nc", "ds_2010.nc", "ds_2011.nc", "ds_2012.nc", "ds_2013.nc", "ds_2014.nc", "ds_2015.nc", "ds_2016.nc", "ds_2017.nc", "ds_2018.nc", "ds_2019.nc", "ds_2020.nc", "ds_2021.nc", "ds_2022.nc", "ds_2023.nc", and "ds_2024.nc" to calculate the average monthly stroke density between latitudes 10.5 and 12 and longitudes -74 and -72. Create a table showing the average stroke density per month across all years and generate a histogram of these monthly averages.

# %% [markdown]
# ## List files
#
# ### Subtask:
# Create a list of all relevant NetCDF files for the years 2005 to 2024.

# %% [markdown]
# **Reasoning**:
# Create a list of file paths for the NetCDF files from 2005 to 2024.

# %%
file_paths = []
for year in range(2005, 2025):
    file_name = f'WWLLN_th_{year}.nc'
    file_paths.append(file_name)

print(file_paths)
